# %%
import pandas as pd

data = {
    'Hours_Studied': [1, 2, 3, 4, 5, 6, 7, 8, 2.5, 3.5, 5.5, 6.5],
    'Attendance': [50, 60, 65, 70, 75, 80, 85, 90, 55, 68, 78, 88],
    'Marks': [35, 40, 45, 50, 55, 65, 70, 80, 42, 48, 60, 72]
}

df = pd.DataFrame(data)
print(df)
# Out:
#     Hours_Studied  Attendance  Marks
# 0             1.0          50     35
# 1             2.0          60     40
# 2             3.0          65     45
# 3             4.0          70     50
# 4             5.0          75     55
# 5             6.0          80     65
# 6             7.0          85     70
# 7             8.0          90     80
# 8             2.5          55     42
# 9             3.5          68     48
# 10            5.5          78     60
# 11            6.5          88     72

# %%
x=df[["Hours_Studied"]]
y=df["Marks"]
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.predict([[9]])
# Out:
# C:\Users\PALLAVI H\miniconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([84.33012821])

# %%
model.coef_#slope(m)
# Out:
# array([6.48076923])

# %%
model.intercept_#intercept(c)
# Out:
# np.float64(26.003205128205124)

# %%
#y=(m*x)+c

# %%
(6.48076923*9)+26.003205128205124 #x=9
# Out:
# 84.33012819820513

# %% [markdown]
# Multiple linear regression

# %%
df.head()
# Out:
#    Hours_Studied  Attendance  Marks
# 0            1.0          50     35
# 1            2.0          60     40
# 2            3.0          65     45
# 3            4.0          70     50
# 4            5.0          75     55

# %%
#feature selection
x=df[["Hours_Studied","Attendance"]]
y=df["Marks"]

# %%
from sklearn.linear_model import LinearRegression
model1=LinearRegression()
model1.fit(x,y)
model1.predict([[9,88]])
# Out:
# C:\Users\PALLAVI H\miniconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([83.04563111])

# %%
model1.coef_
# Out:
# array([5.75038072, 0.1251407 ])

# %%
model1.intercept_
# Out:
# np.float64(20.279822993224293)

# %%
model1.predict([[1,50]])
# Out:
# C:\Users\PALLAVI H\miniconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([32.28723874])

# %%
x=df[["Hours_Studied","Attendance"]]
y=df["Marks"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(x_train)
# Out:
#     Hours_Studied  Attendance
# 8             2.5          55
# 5             6.0          80
# 2             3.0          65
# 1             2.0          60
# 11            6.5          88
# 4             5.0          75
# 7             8.0          90
# 3             4.0          70
# 6             7.0          85

# %%
mlr=LinearRegression().fit(x_train,y_train)

# %%
y_pred=mlr.predict(x_test)
y_pred
# Out:
# array([61.85624547, 48.69893809, 30.96309207])

# %%
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error

# %%
print("Error= ",mean_squared_error(y_pred,y_test))
print("R2 Score= ",r2_score(y_pred,y_test))
print("MAE= ",mean_absolute_error(y_pred,y_test))
# Out:
# Error=  6.7435957672980615
# R2 Score=  0.957912790023541
# MAE=  2.1973638291589452

# %%
import pandas as pd
data = {
    'Age': [25, 40, 35, 50, 23, 45, 52, 33],
    'Balance': [20000, 50000, 30000, 80000, 15000, 60000, 90000, 40000],
    'Active': [1, 0, 1, 0, 1, 0, 0, 1],
    'Churn': [0, 1, 0, 1, 0, 1, 1, 0]
}

df = pd.DataFrame(data)
df
# Out:
#    Age  Balance  Active  Churn
# 0   25    20000       1      0
# 1   40    50000       0      1
# 2   35    30000       1      0
# 3   50    80000       0      1
# 4   23    15000       1      0
# 5   45    60000       0      1
# 6   52    90000       0      1
# 7   33    40000       1      0

# %%
from sklearn.linear_model import LogisticRegression

# %%
a=LogisticRegression()

# %%
y=df["Churn"]

# %%
x=df[["Age","Balance","Active"]]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
print(x_train)
# Out:
#    Age  Balance  Active
# 7   33    40000       1
# 2   35    30000       1
# 4   23    15000       1
# 3   50    80000       0
# 6   52    90000       0

# %%
a.fit(x_train,y_train)
# Out:
# C:\Users\PALLAVI H\miniconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred=a.predict(x_test)
y_pred
# Out:
# array([0, 1, 0])

# %%
a.predict([[25,20000,1]])
# Out:
# C:\Users\PALLAVI H\miniconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
a.predict([[50,79000,0]])
# Out:
# C:\Users\PALLAVI H\miniconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
print("Accuracy= ",accuracy_score(y_test,y_pred))
print("Confusion_Matrix= \n",confusion_matrix(y_test,y_pred))
print("Classification_report= ",classification_report(y_test,y_pred))
# Out:
# Accuracy=  0.6666666666666666
# Confusion_Matrix=
#  [[1 0]
#  [1 1]]
# Classification_report=                precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         1
#            1       1.00      0.50      0.67         2
#
#     accuracy                           0.67         3
#    macro avg       0.75      0.75      0.67         3
# weighted avg       0.83      0.67      0.67         3

# %%
import numpy as np

# %%
x=np.array([30,40000,1])

# %%
w=np.array([0.2,0.00001,0.5])

# %%
b=0.1

# %%
z=np.dot(x,w)+b
print("Weighted Sum is:",z)
# Out:
# Weighted Sum is: 7.0

# %%
#Activation function
def sigmoid(x):
    return 1 / (1 + np.exp(-z))
output=sigmoid(z)
print("Neuron Output:",output)
# Out:
# Neuron Output: 0.9990889488055994

# %%
if(output>0.5):
    print("Churned")
else:
    print("Not churned")
# Out:
# Churned

# %%
import pandas as pd

data = {
    'Hours_Studied': [1, 2, 3, 4, 5, 6, 7, 8, 2.5, 3.5, 5.5, 6.5],
    'Attendance': [50, 60, 65, 70, 75, 80, 85, 90, 55, 68, 78, 88],
    'Marks': [35, 40, 45, 50, 55, 65, 70, 80, 42, 48, 60, 72]
}

df = pd.DataFrame(data)
print(df)
# Out:
#     Hours_Studied  Attendance  Marks
# 0             1.0          50     35
# 1             2.0          60     40
# 2             3.0          65     45
# 3             4.0          70     50
# 4             5.0          75     55
# 5             6.0          80     65
# 6             7.0          85     70
# 7             8.0          90     80
# 8             2.5          55     42
# 9             3.5          68     48
# 10            5.5          78     60
# 11            6.5          88     72

# %%
import numpy as  np

# %%
x=np.array([2,40])

# %%
w=np.array([0.1,0.2])

# %%
b=0.3

# %%
z=np.dot(x,w)+b
print("Weighted Sum is:",z)
# Out:
# Weighted Sum is: 8.5

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-z))
output=sigmoid(z)
print("Neuron Output:",output)
# Out:
# Neuron Output: 0.9997965730219448

# %%
w1=np.array([[0.5,0.2],
             [0.3,0.7]])
b1=np.array([1,1])
hidden=np.dot(w1,x)+b1
print("Hidden Layer Output:",hidden)
# Out:
# Hidden Layer Output: [10.  29.6]

# %%
w2=np.array([0.2,0.7])
h=np.dot(w2,x)+b1
print(h)
# Out:
# [29.4 29.4]

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))
output=sigmoid(h)
print("Neuron Output:",output)
# Out:
# Neuron Output: [1. 1.]

# %%
import sys
print(sys.version)
print(sys.executable)
# !pip --version
# Out:
# 3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:09:58) [MSC v.1929 64 bit (AMD64)]
# C:\Users\PALLAVI H\miniconda3\python.exe
# pip 25.2 from C:\Users\PALLAVI H\miniconda3\Lib\site-packages\pip (python 3.13)

# %%
# !pip install tensorflow

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
model=Sequential([
    Dense(10, activation='relu', input_shape=(2,)),
    Dense(5, activation='relu'),
    Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 from tensorflow.keras.models import Sequential
#       2 from tensorflow.keras.layers import Dense
#       3 model=Sequential([
#       4     Dense(10, activation='relu', input_shape=(2,)),
#       5     Dense(5, activation='relu'),
#       6     Dense(1, activation='sigmoid')
#       7 ])
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
import math
1/(1+math.exp(-1000))

# %%
import numpy as np
1/(1+np.exp(-(1000)))

# %%
import numpy as np

# %%
def sigmoid(x):
    return 1 / (1 +np.exp(-x))
def tanh(x):
    return np.tanh(x)
def relu(x):
    return np.maximum(0,x)

# %%
x=np.linspace(-10,10,100)
x

# %%
s=np.array([-2,-3,0,1,18])
print("Sigmoid:",sigmoid(s))
print("TanH:",tanh(s))
print("Relu:",relu(s))

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_classification

# %%
X, y = make_classification(n_samples=1000, n_features=20, random_state=42)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

print("Data Ready")
# Out:
# Data Ready
